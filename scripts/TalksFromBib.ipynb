# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

import shutil
mydir = "../_talks"
if os.path.exists(mydir):
    shutil.rmtree(mydir)
os.makedirs(mydir)

# %%
def process_pubs(type):
    cnt_pub = 0
    for pubsource in publist:
        parser = bibtex.Parser()
        bibdata = parser.parse_file(publist[pubsource]["file"])

        #loop through the individual references in a given bibtex file
        for bib_id in bibdata.entries:
            #reset default date
            pub_year = "1900"
            pub_month = "01"
            pub_day = "01"
            
            b = bibdata.entries[bib_id].fields
            
            try:
                pub_year = f'{b["year"]}'

                #todo: this hack for month and day needs some cleanup
                if "month" in b.keys(): 
                    if(len(b["month"])<3):
                        pub_month = "0"+b["month"]
                        pub_month = pub_month[-2:]
                    elif(b["month"] not in range(12)):
                        tmnth = strptime(b["month"][:3],'%b').tm_mon   
                        pub_month = "{:02d}".format(tmnth) 
                    else:
                        pub_month = str(b["month"])
                if "day" in b.keys(): 
                    pub_day = str(b["day"])

                    
                pub_date = pub_year+"-"+pub_month+"-"+pub_day
                
                #strip out {} as needed (some bibtex entries that maintain formatting)
                clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

                url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
                url_slug = url_slug.replace("--","-")

                md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
                html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

                #Build Citation from text
                citation = ""

                """
                #citation authors - todo - add highlighting for primary author?
                n_authors = len(bibdata.entries[bib_id].persons["author"])
                cnt = 0
                for author in bibdata.entries[bib_id].persons["author"]:
                    cnt += 1
                    if author.last_names[0] == "Iserte":
                        citation = citation +" <strong>" + author.first_names[0][0] + ". "+author.last_names[0] + "</strong>"
                    else:
                        citation = citation + " " + author.first_names[0][0] + ". " + author.last_names[0]
                    if cnt == n_authors-1:
                        citation = citation + ", and "
                    else:
                        citation = citation + ", "
                """
                        
                #citation title
                citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

                #add venue logic depending on citation type
                venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

                citation = citation + " " + html_escape(venue)
                if str(b["month"]) == "May":
                    month = "May"
                else:
                    month = str(b["month"])[0:3] + "."
                citation = citation + ", " + month + " " + pub_year + "."

                ## YAML variables
                md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
                md += """collection: """ +  publist[pubsource]["collection"]["name"]
                md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
                md += "\ntype: \"" + type + "\""
                md += "\nlocation: \"" + b["address"] + "\""
                
                note = False
                if "note" in b.keys():
                    if len(str(b["note"])) > 5:
                        md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                        note = True

                md += "\ndate: " + str(pub_date) 

                md += "\nvenue: '" + html_escape(venue) + "'"
                
                if "url" in b.keys():
                    if len(str(b["url"])) > 5:
                        md += "\nurl: '" + b["url"] + "'"

                #md += "\ncitation: '" + html_escape(citation) + "'"

                md += "\n---"

                md_filename = os.path.basename(md_filename)

                with open(mydir + "/" + md_filename, 'w', encoding="utf-8") as f:
                    f.write(md)
                print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
            # field may not exist for a reference
            except KeyError as e:
                print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
                continue
            cnt_pub += 1
    return cnt_pub

# %%
type_list=["conference", "workshop", "seminar", "national"]
for type in type_list:
    publist = {
    "journal":{
        "file": "talks-bib/" + type + ".bib",
        "venuekey" : "booktitle",
        "venue-pretext" : "",
        "collection" : {"name":"talks",
                        "permalink":"/talks/"}
        } 
    }
    print(process_pubs(type))
# Out:
# SUCESSFULLY PARSED closer2016: " Enabling GPU Virtualization in Cloud Environments  "
# SUCESSFULLY PARSED sbacpad2014: " Slurm Support for Remote GPU Virtualization: Implementation  ... "
# 2
# SUCESSFULLY PARSED p2s22017: " Efficient Scalable Computing through Flexible Applications a ... "
# SUCESSFULLY PARSED smcdc212021: " A Study on the Resource Utilization and User Behavior on Tit ... "
# SUCESSFULLY PARSED jlesc2023: " Fostering the Development of Malleable Applications  "
# SUCESSFULLY PARSED llvmhpc232023: " DPU Offloading Programming with the OpenMP API  "
# SUCESSFULLY PARSED exampi232023: " Efficient Data Redistribution for Malleable Applications  "
# SUCESSFULLY PARSED jlesc2024: " Efficient Cluster Resource Utilization in HPC Applications  "
# SUCESSFULLY PARSED middlewareconf2018: " Boosting Productivity through Efficient Resource Management  "
# SUCESSFULLY PARSED pact18: " Productivity-enhancing Malleability for HPC Applications  "
# SUCESSFULLY PARSED sarteco2018: " High-throughput Computation through Efficient Resource Manag ... "
# SUCESSFULLY PARSED nesus2016: " Dynamic Management of Resource Allocation for OmpSs Jobs  "
# 10
# SUCESSFULLY PARSED riscvsummit2023: " MPI Malleability with the DMR Library  "
# SUCESSFULLY PARSED bscseminars2023: " Increasing Productivity with Malleability  "
# SUCESSFULLY PARSED politechnika2022: " HPC & AI: a Malleable Approach  "
# SUCESSFULLY PARSED vhpc2020: " Managing Cloudified GPUs with GSaaS  "
# SUCESSFULLY PARSED awsday2015: " GPU Virtualization in AWS Virtual Machines  "
# SUCESSFULLY PARSED slurmtraining2015: " Managing Virtualized Remote GPUs with Slurm  "
# SUCESSFULLY PARSED slurmusergroup2014: " Slurm Support for Remote GPU Virtualization: Implementation  ... "
# 7
# SUCESSFULLY PARSED sarteco2023: " Maleabilidad MPI basada en la eficiencia paralela  "
# SUCESSFULLY PARSED sarteco2017: " El camino desde la maleabilidad MPI hasta las cargas de trab ... "
# SUCESSFULLY PARSED sarteco2015: " Comparativa de políticas de selección de GPUs remotas en clú ... "
# SUCESSFULLY PARSED sarteco2014: " Extendiendo Slurm con soporte para el uso de GPUs remotas  "
# SUCESSFULLY PARSED sarteco2013: " Un planificador de GPUs remotas para clústers HPC  "
# 5
